# %% [raw]
# Name - Dhanraj Pallepati
# Course Number - HDS 5230
# Assignment Number - Week 05 Dask Programming Assignment

# %%
import pandas as pd
import dask.dataframe as dd
import numpy as np
from datetime import datetime

# %%
dtypes = {
    'aggregate': 'object',
    'cases': 'float64',
    'city': 'object',
    'population': 'float64',
    'deaths': 'float64',
    'country': 'object',
    'state': 'object',
    'date': 'object'
}

# %%
df = dd.read_csv("timeseries.csv",dtype=dtypes)

# %% [raw]
# The operation makes perfect sense to parallelize because the CSV file size is considerable. Fire can improve file loading speed because it splits the file into portions which workers independently read. Parallelization of CSV reading activities offers substantial benefits for systems with multiple cores or machines because this operation exists in the I/O bound category.

# %%
# Filter for US states only and state-level data
us_df = df[(df['country'] == 'United States') & (df['aggregate'] == 'state')]

# %% [raw]
# We derive us_df by filtering df to those records where country equals 'United States' while aggregate equals 'state'.
# The applicable partition parallelization for this filtering step would most likely produce marginal performance gains. The procedure remains straightforward while the distribution costs potentially surpass the achievable advantages. The current utilization of Dask DataFrame ensures we can parallelize subsequent operations because we maintain a distributed data structure.

# %%
# Define date range
start_date = '2020-01-01'
end_date = '2021-02-28'
mask = (us_df['date'] >= start_date) & (us_df['date'] <= end_date)
period_df = us_df[mask]

# %% [raw]
# Date filtering operates in a fashion comparable to the country/state filtering strategy. Parallelization is possible for this operation but the distribution costs might exceed its benefits. The data distribution remains beneficial to maintain because the current filtered dataset possesses a substantial size.

# %%
state_metrics = period_df.groupby('state').agg({
    'deaths': 'sum',
    'population': 'mean'
}).compute()

state_metrics['per_capita_mortality'] = state_metrics['deaths'] / state_metrics['population']
state_metrics['mortality_rank'] = state_metrics['per_capita_mortality'].rank(ascending=False)

print(state_metrics.sort_values('mortality_rank'))
# Out:
#                                  deaths  population  per_capita_mortality  \
# state
# New Jersey                     861317.0   8882190.0              0.096971
# Connecticut                    277777.0   3565287.0              0.077912
# Massachusetts                  482980.0   6892503.0              0.070073
# New York                      1358824.0  19453561.0              0.069850
# Louisiana                      213399.0   4648794.0              0.045904
# Washington, D.C.                32225.0    705749.0              0.045661
# Rhode Island                    46435.0   1059361.0              0.043833
# Michigan                       419841.0   9986857.0              0.042039
# Pennsylvania                   378963.0  12801989.0              0.029602
# Maryland                       175443.0   6045680.0              0.029020
# Delaware                        25878.0    973764.0              0.026575
# Mississippi                     52399.0   2976149.0              0.017606
# Georgia                        155394.0  10617423.0              0.014636
# Ohio                           154003.0  11689100.0              0.013175
# New Hampshire                   17373.0   1359711.0              0.012777
# Minnesota                       71447.0   5639632.0              0.012669
# Washington                      92668.0   7614893.0              0.012169
# New Mexico                      24629.0   2096829.0              0.011746
# Iowa                            35896.0   3155070.0              0.011377
# Virginia                        93598.0   8535519.0              0.010966
# Nevada                          31220.0   3080156.0              0.010136
# Alabama                         46778.0   4903185.0              0.009540
# Missouri                        53833.0   6137428.0              0.008771
# Wisconsin                       44411.0   5822434.0              0.007628
# Vermont                          4547.0    623989.0              0.007287
# South Carolina                  37414.0   5148714.0              0.007267
# Oklahoma                        25484.0   3956971.0              0.006440
# North Carolina                  66131.0  10488084.0              0.006305
# Kansas                          16352.0   2913314.0              0.005613
# North Dakota                     4217.0    762062.0              0.005534
# Maine                            6575.0   1344212.0              0.004891
# South Dakota                     4202.0    884659.0              0.004750
# Arizona                         34469.0   7278717.0              0.004736
# Tennessee                       30189.0   6829174.0              0.004421
# Texas                          125448.0  28995881.0              0.004326
# Arkansas                        11456.0   3017804.0              0.003796
# Idaho                            6398.0   1787065.0              0.003580
# West Virginia                    5469.0   1792147.0              0.003052
# Oregon                          12575.0   4217737.0              0.002981
# Utah                             8190.0   3205958.0              0.002555
# United States Virgin Islands      248.0    104901.0              0.002364
# Northern Mariana Islands          106.0     55144.0              0.001922
# Wyoming                          1032.0    578759.0              0.001783
# Puerto Rico                      5696.0   3411307.0              0.001670
# Guam                              266.0    167772.0              0.001585
# Montana                          1398.0   1068778.0              0.001308
# Alaska                            824.0    731545.0              0.001126
# American Samoa                      0.0     55689.0              0.000000
#
#                               mortality_rank
# state
# New Jersey                               1.0
# Connecticut                              2.0
# Massachusetts                            3.0
# New York                                 4.0
# Louisiana                                5.0
# Washington, D.C.                         6.0
# Rhode Island                             7.0
# Michigan                                 8.0
# Pennsylvania                             9.0
# Maryland                                10.0
# Delaware                                11.0
# Mississippi                             12.0
# Georgia                                 13.0
# Ohio                                    14.0
# New Hampshire                           15.0
# Minnesota                               16.0
# Washington                              17.0
# New Mexico                              18.0
# Iowa                                    19.0
# Virginia                                20.0
# Nevada                                  21.0
# Alabama                                 22.0
# Missouri                                23.0
# Wisconsin                               24.0
# Vermont                                 25.0
# South Carolina                          26.0
# Oklahoma                                27.0
# North Carolina                          28.0
# Kansas                                  29.0
# North Dakota                            30.0
# Maine                                   31.0
# South Dakota                            32.0
# Arizona                                 33.0
# Tennessee                               34.0
# Texas                                   35.0
# Arkansas                                36.0
# Idaho                                   37.0
# West Virginia                           38.0
# Oregon                                  39.0
# Utah                                    40.0
# United States Virgin Islands            41.0
# Northern Mariana Islands                42.0
# Wyoming                                 43.0
# Puerto Rico                             44.0
# Guam                                    45.0
# Montana                                 46.0
# Alaska                                  47.0
# American Samoa                          48.0

# %% [raw]
# A parallelization approach brings value to the groupby-aggregate operation because it requires consolidating information from extensive state datasets. The computation involves splitting state aggregations among separate workers which creates an embarrassingly parallel opportunity for this problem. The compute() command enables quick combination of data from all participating workers.

# %%
period_df = period_df.compute()
period_df['date'] = pd.to_datetime(period_df['date'])
period_df['month_year'] = period_df['date'].dt.strftime('%Y-%m')
monthly_metrics = period_df.groupby(['state', 'month_year']).agg({
    'deaths': 'last',
    'cases': 'last'
}).reset_index()

# Calculate CFR (Case Fatality Rate)
monthly_metrics['cfr'] = monthly_metrics['deaths'] / monthly_metrics['cases']
cfr_matrix = monthly_metrics.pivot(index='state', columns='month_year', values='cfr')
print(cfr_matrix)
# Out:
# C:\Users\91849\anaconda3\Lib\site-packages\dask\dataframe\io\csv.py:195: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# Louisiana                     0.053586  0.050409
# Maine                         0.032298  0.031918
# Maryland                      0.046382  0.046573
# Massachusetts                 0.074102  0.074408
# Michigan                      0.087641  0.085247
# Minnesota                     0.039785  0.039543
# Mississippi                   0.039379  0.035955
# Missouri                      0.050752  0.043864
# Montana                       0.022751  0.018977
# Nevada                        0.027284  0.023820
# New Hampshire                 0.064176  0.064197
# New Jersey                    0.086968  0.087721
# New Mexico                    0.040915  0.039271
# New York                      0.051655  0.062710
# North Carolina                0.020934  0.019128
# North Dakota                  0.022092  0.023323
# Northern Mariana Islands      0.066667  0.064516
# Ohio                          0.055282  0.050935
# Oklahoma                      0.028133  0.024987
# Oregon                        0.024126  0.021017
# Pennsylvania                  0.073389  0.075155
# Puerto Rico                   0.025659  0.019581
# Rhode Island                  0.060674  0.056501
# South Carolina                0.020303  0.018284
# South Dakota                  0.013454  0.013734
# Tennessee                     0.013944  0.012561
# Texas                         0.014889  0.013507
# United States Virgin Islands  0.083333  0.054054
# Utah                          0.007199  0.007374
# Vermont                       0.046589  0.044836
# Virginia                      0.028098  0.028183
# Washington                    0.038592  0.038415
# Washington, D.C.              0.053355  0.053330
# West Virginia                 0.032025  0.028817
# Wisconsin                     0.027242  0.023115
# Wyoming                       0.013450  0.012240

# %% [raw]
# Changing calculations to pandas (compute()) data makes logical sense due to the following considerations:
#
# The dataset has undergone significant reduction because of the applied state-level grouping process.
# The date operations and pivot operations require advanced and complex programming which Dask only partly supports
# At this stage the needed memory storage remains within a manageable range
# The expenses of executing distributed computations surpass what this approach delivers.

# %%
cfr_changes = cfr_matrix.diff(axis=1)
total_change = cfr_changes.abs().sum(axis=1)
cfr_rankings = total_change.rank(ascending=True)
print(cfr_rankings.sort_values())
# Out:
# state
# American Samoa                   1.0
# West Virginia                    2.0
# South Dakota                     3.0
# Utah                             4.0
# Wyoming                          5.0
# Arkansas                         6.0
# Delaware                         7.0
# Montana                          8.0
# Iowa                             9.0
# Alaska                          10.0
# North Dakota                    11.0
# Tennessee                       12.0
# Guam                            13.0
# Minnesota                       14.0
# Texas                           15.0
# Idaho                           16.0
# Virginia                        17.0
# Georgia                         18.0
# Oregon                          19.0
# Washington, D.C.                20.0
# Arizona                         21.0
# Mississippi                     22.0
# New Mexico                      23.0
# Kansas                          24.0
# Louisiana                       25.0
# Puerto Rico                     26.0
# Alabama                         27.0
# Vermont                         28.0
# South Carolina                  29.0
# Ohio                            30.0
# North Carolina                  31.0
# Nevada                          32.0
# Maine                           33.0
# Maryland                        34.0
# New Hampshire                   35.0
# Oklahoma                        36.0
# Wisconsin                       37.0
# Rhode Island                    38.0
# United States Virgin Islands    39.0
# Massachusetts                   40.0
# Pennsylvania                    41.0
# New Jersey                      42.0
# Missouri                        43.0
# Michigan                        44.0
# New York                        45.0
# Connecticut                     46.0
# Northern Mariana Islands        47.0
# Washington                      48.0
# dtype: float64

# %% [raw]
# The operations deal with matrices with dimensions of 50 states by 14 months while demanding complete row or column views to conduct computations. The added cost of distributing these operations exceeds their occurred benefits. The computational speed of pandas satisfies operational needs because it supports instant calculations and utilizes memory-based operations that perform reliably.
